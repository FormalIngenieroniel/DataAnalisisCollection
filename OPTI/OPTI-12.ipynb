# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression

# %%
salesDit = pd.read_csv('stores-dist.csv')
salesDit.columns = ['district','sales','stores']

salesDit.head()
# Out:
#    district  sales  stores
# 0         1  231.0      12
# 1         2  156.0      13
# 2         3   10.0      16
# 3         4  519.0       2
# 4         5  437.0       6

# %%
sales = salesDit.drop('district', axis=1)
sales.head()
# Out:
#    sales  stores
# 0  231.0      12
# 1  156.0      13
# 2   10.0      16
# 3  519.0       2
# 4  437.0       6

# %%
y = sales.sales
x = sales.stores

# %%
order = 1
p = np.poly1d(np.polyfit(x,y,order))

print('p(x) tiene el valor polinomial de cada y para cada x,\n\n{}.'.format(p(x)))
print('\nEl vector de coeficientes p describe el modelo de regresion:\n{}'.format(p))
print('\nEl p[0]: {}.'.format(p[0]))
print('\nEl p[1]: {}.'.format(p[1]))
# Out:
# p(x) tiene el valor polinomial de cada y para cada x,
#
# [169.93468442 134.14759895  26.78634257 527.80553905 384.65719719
#  420.44428266 205.72176988 134.14759895  26.78634257 277.29594081
#  527.80553905 313.08302627 456.23136812  62.57342803 169.93468442
#  205.72176988 420.44428266  98.36051349 313.08302627 527.80553905
#  563.59262451  62.57342803 134.14759895 348.87011173 384.65719719
#  563.59262451 277.29594081].
#
# El vector de coeficientes p describe el modelo de regresion:
#
# -35.79 x + 599.4
#
# El p[0]: 599.3797099726614.
#
# El p[1]: -35.787085462974005.

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y,p(x))
r2
# Out:
# 0.83217523508888

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,p(x))
mse
# Out:
# 5961.386465941158

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y,p(x))
mae
# Out:
# 61.2232611786873
